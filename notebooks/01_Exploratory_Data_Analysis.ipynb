# %% [markdown]
# # 01 - Análise Exploratória de Dados (EDA)
#
# Projeto: Previsão de Aprovação baseado em características do estudante.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/synthetic_data.csv')
print(df.head())
print(df.describe())
